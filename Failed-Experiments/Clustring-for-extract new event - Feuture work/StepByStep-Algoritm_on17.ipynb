# %%
# in the name of god

# %%
import pandas as pd 
import numpy as np
from IPython.display import clear_output
import time
import pickle

import matplotlib.pyplot as plt
from matplotlib.cbook import flatten
import matplotlib.cm as cm
import matplotlib as matplotlib

def color_map_color(value, cmap_name='coolwarm', vmin=0, vmax=10):
    # norm = plt.Normalize(vmin, vmax)
    norm = matplotlib.colors.Normalize(vmin=vmin, vmax=vmax)
    cmap = cm.get_cmap(cmap_name)  # PiYG
    rgb = cmap(norm(abs(value)))[:3]  # will return rgba, we take only first 3 so we get rgb
    color = matplotlib.colors.rgb2hex(rgb)
    return color

# Display figures inline in Jupyter notebook
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(15, 5)})

# %%
#prepare Dataset gyroscope
dfg=pd.read_csv('17\giroscopio_terra.csv')
dfg['ts']=pd.to_datetime(dfg.apply(lambda x:(round((x.uptimeNanos-dfg.uptimeNanos[0])/1000000)*1000000),axis=1))
dm=dfg['ts']
dfg=dfg.drop('uptimeNanos',1).drop('timestamp',1)
dfg=dfg.set_index('ts').rename(columns={'x': 'g-x','y': 'g-y','z': 'g-z'})
dfg.head(3)
# Out:
#                               g-x       g-y       g-z
# ts
# 1970-01-01 00:00:00.000  0.030578 -0.035392 -0.033423
# 1970-01-01 00:00:00.010 -0.007943 -0.017933 -0.022102
# 1970-01-01 00:00:00.025 -0.005299 -0.041667 -0.008381

# %%
#prepare Dataset accelarator
dfa=pd.read_csv('17\\acelerometro_terra.csv')
dfa['ts']=dm
dfa=dfa.drop('uptimeNanos',1).drop('timestamp',1)
dfa=dfa.set_index('ts').rename(columns={'x': 'a-x','y': 'a-y','z': 'a-z'})
dfa.head(3)
# Out:
#                               a-x       a-y       a-z
# ts
# 1970-01-01 00:00:00.000 -0.047600  0.004670  9.852109
# 1970-01-01 00:00:00.010 -0.066993  0.060984  9.634208
# 1970-01-01 00:00:00.025 -0.200131  0.170454  9.512366

# %%
df = pd.concat([dfa, dfg], axis=1, join='outer')
df.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE19AD63C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE197F5CC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE19835488>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE19868F48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE198A4BC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001DE198DD808>],
#       dtype=object)

# %%
evented_label
# Out:
# [('troca_faixa_direita_agressiva',
#   Timestamp('1970-01-01 00:00:16.100000'),
#   Timestamp('1970-01-01 00:00:18.500000')),
#  ('troca_faixa_direita_agressiva',
#   Timestamp('1970-01-01 00:00:25.100000'),
#   Timestamp('1970-01-01 00:00:27.600000')),
#  ('freada_agressiva',
#   Timestamp('1970-01-01 00:02:21'),
#   Timestamp('1970-01-01 00:02:23.300000')),
#  ('freada_agressiva',
#   Timestamp('1970-01-01 00:02:31.300000'),
#   Timestamp('1970-01-01 00:02:33.200000')),
#  ('freada_agressiva',
#   Timestamp('1970-01-01 00:02:45.900000'),
#   Timestamp('1970-01-01 00:02:48')),
#  ('freada_agressiva',
#   Timestamp('1970-01-01 00:03:40.600000'),
#   Timestamp('1970-01-01 00:03:42.600000')),
#  ('freada_agressiva',
#   Timestamp('1970-01-01 00:03:54'),
#   Timestamp('1970-01-01 00:03:56.200000')),
#  ('freada_agressiva',
#   Timestamp('1970-01-01 00:04:08.100000'),
#   Timestamp('1970-01-01 00:04:10.800000')),
#  ('aceleracao_agressiva',
#   Timestamp('1970-01-01 00:04:48'),
#   Timestamp('1970-01-01 00:04:50.600000')),
#  ('aceleracao_agressiva',
#   Timestamp('1970-01-01 00:05:04.600000'),
#   Timestamp('1970-01-01 00:05:08.200000')),
#  ('aceleracao_agressiva',
#   Timestamp('1970-01-01 00:05:24.800000'),
#   Timestamp('1970-01-01 00:05:29.100000')),
#  ('aceleracao_agressiva',
#   Timestamp('1970-01-01 00:06:01'),
#   Timestamp('1970-01-01 00:06:04.700000')),
#  ('aceleracao_agressiva',
#   Timestamp('1970-01-01 00:06:19.600000'),
#   Timestamp('1970-01-01 00:06:24.500000')),
#  ('aceleracao_agressiva',
#   Timestamp('1970-01-01 00:06:35.700000'),
#   Timestamp('1970-01-01 00:06:40.200000'))]

# %%
#prepare Labeled dataset
dfl=pd.read_csv('17\\groundTruth.csv')
dfl['length']=dfl.en-dfl.st
lmean=dfl.length.mean()
lstd=dfl.length.std()

#extract the labels for clutering precision its for after clustering
def time_convertor(x):
    s,h,m=0,0,0
    s=round(x%60,2)
    m=int(x/60)
    h=int(m/60)
    m=m%60
    time=str(h)+':'+str(m)+':'+str(s)
    return pd.to_datetime('1970-01-01 '+time)

dfl['st_time']=dfl.apply(lambda x:time_convertor(x.st) ,axis=1 )
dfl['en_time']=dfl.apply(lambda x:time_convertor(x.en) ,axis=1 )
dfl=dfl.drop('st',1).drop('en',1).drop('length',1)
evented_label=list()
for i in range(len(dfl)):
    evented_label.append((dfl.iloc[i][0],dfl.iloc[i][1],dfl.iloc[i][2]))

# %%
#Dont RUN this part
#we should optimize M
#lengh of random event
from random import gauss
L=round(gauss(lmean,lstd)*50)
M=round(gauss(0.5,0.5)*50)

temp_event=list()
pointer=0
stop=False
#go on timeserise for event extraction
while stop!=True:
    clear_output(wait=True)
    M=round(gauss(0.5,0.5)*50)
    pointer=pointer + M
    #go forward till reach M
    L=round(gauss(lmean,lstd)*50)
    l_min=pointer-int(L/2)
    l_max=pointer+int(L/2)
    if (l_min<0):
        l_min=0
    if (l_max>len(df)):
        l_max=len(df)
        stop=True

    print('extraction ',l_max/len(df),' %  is complete')
    
    temp_event.append(df[l_min:l_max])
# Out:
# extraction  1.0  %  is complete

# %%
#Dont RUN this part
#calculate distance
from fastdtw import fastdtw
distance=list()
n=0
k=(len(temp_event))
k=k*k
t1=time.time()
for i,x in enumerate(temp_event):
    dumy=list()
    for j,y in enumerate(temp_event):
        clear_output(wait=True)
        n=n+1
        print('disstance calculatoin ',round((n/k)*100,4),' %  is complete')
        if (i<=j):
            continue
        else:
            dist,_=fastdtw(x,y)
            dumy.append(dist)
        
    distance.append(dumy)
t2=time.time()
print(round((t2-t1)/60) ,'min has time for calculaton distant')
# Out:
# disstance calculatoin  100.0  %  is complete
# 268 min has time for calculaton distant

# %%
#Dont RUN this part
#clustering precision
n=0
k=len(temp_event)*len(evented_label)
labels_distance=list()

for tag,st,en in evented_label:
    dummy=list()
    for t_e in temp_event:
        clear_output(wait=True)
        n=n+1
        print('disstance calculatoin ',round((n/k)*100,2),' %  is complete')
        dist,_=fastdtw(df[st:en],t_e)
        dummy.append(dist)
    labels_distance.append((tag,dummy))
# Out:
# disstance calculatoin  100.0  %  is complete

# %%
#Save temp_event
with open("temp_event_on17.txt", "wb") as fp:
    pickle.dump(temp_event, fp)
    
#Save distance matrix
with open("distance_on17.txt", "wb") as fp:
    pickle.dump(distance, fp)
    
#Save labeds distance matrix
with open("labels_distance_on17.txt", "wb") as fp:
    pickle.dump(labels_distance, fp)

# %%
#load File , save the time of calculation
with open("temp_event_on17.txt", "rb") as fp:
    te = pickle.load(fp)
with open("distance_on17.txt", "rb") as fp:
    dc = pickle.load(fp)
with open("labels_distance_on17.txt", "rb") as fp:
    ld = pickle.load(fp)

# %%
#make it as matrix 
#full it with zero for squaring
from copy import deepcopy
def creat_Symmetric_matrix(file):  
    MTX=deepcopy(file)
    for i in range(len(MTX)):
        while len(MTX[i])!=len(MTX):
            MTX[i].append(0)
    #make it Symmetry from diameter
    arr=np.array(MTX)
    dis=np.array(MTX)
    for i in range(len(arr)):
        for j in range(len(arr)):
            if (i>j):
                dis[j][i]=arr[i][j]
    return dis
dis=creat_Symmetric_matrix(dc)

# %%
#PLOT GRAPH
import networkx as nx
G = G=nx.from_numpy_matrix(dis)
nx.draw(G,edge_color ='w', edge_cmap=plt.cm.winter ,node_color='r')

# %%
#initial clustering
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster import hierarchy

cluster = AgglomerativeClustering(n_clusters=4, affinity='precomputed', linkage = 'average').fit(dis)

plot_list=list()
for i,el in enumerate(te):
    plot_list.append((el,cluster.labels_[i]))
    
fig, ax = plt.subplots()

for el in plot_list:
    ax.plot(el[0], linestyle='-', linewidth=2,c=color_map_color(el[1]*10))
ax.legend();
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Z = hierarchy.linkage(dis, 'complete')
plt.figure()
dn = hierarchy.dendrogram(Z)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   """Entry point for launching an IPython kernel.

# %%
color_map = []
for cl in cluster.labels_:
    color_map.append(color_map_color(cl*10))

nx.draw(G,edge_color ='w', node_color=color_map)
plt.show()

# %%
#calculate the precision of clustering by labeled data 
exploratory_analysis=list()
for el in ld:
    midle_list=list()
    label_tag =el[0]
    label_distance=el[1].copy()
    label_distance.append(0)
    distance_matrix=dc.copy()
    distance_matrix.append(label_distance)
    DMX=creat_Symmetric_matrix(distance_matrix)
    Labels = AgglomerativeClustering(n_clusters=4, affinity='precomputed', linkage = 'average').fit(DMX).labels_

    #extract lable  and labele it from the item we put at the end
    for i , x in enumerate(Labels):
        if i!=(len(Labels)-1):
            if x==Labels[-1]:
                midle_list.append(i)
    exploratory_analysis.append([label_tag,midle_list])
actg=dict()
for ev,x in exploratory_analysis:
    if ev in actg:
        actg[ev].append(x)
    else:
        actg.update({ev:[x]})

# %%
#calculate the Probibility of being event of temp_event
Prob_threshold=0.2
precision=list()

for event_name in actg:
    flat_list=list(dict.fromkeys(flatten(actg[event_name])))
    dprecision=list()
    for S in flat_list:
        x=0
        Number=len(actg[event_name])
        for i in range(Number):
            if S in actg[event_name][i]:
                x=x+1
        Probability=x/Number
        if Probability > Prob_threshold:
            dprecision.append((S,Probability))
    precision.append((event_name,dprecision))

# %%
precision[0]
# Out:
# ('troca_faixa_direita_agressiva',
#  [(0, 1.0),
#   (1, 1.0),
#   (2, 1.0),
#   (3, 1.0),
#   (4, 1.0),
#   (5, 1.0),
#   (6, 1.0),
#   (7, 1.0),
#   (8, 1.0),
#   (9, 1.0),
#   (10, 1.0),
#   (11, 1.0),
#   (12, 1.0),
#   (13, 1.0),
#   (14, 1.0),
#   (15, 1.0),
#   (16, 1.0),
#   (17, 1.0),
#   (18, 1.0),
#   (19, 1.0),
#   (20, 1.0),
#   (21, 1.0),
#   (27, 1.0),
#   (28, 1.0),
#   (29, 1.0),
#   (30, 1.0),
#   (31, 1.0),
#   (32, 1.0),
#   (33, 1.0),
#   (34, 1.0),
#   (35, 1.0),
#   (36, 1.0),
#   (37, 1.0),
#   (38, 1.0),
#   (39, 1.0),
#   (42, 1.0),
#   (43, 1.0),
#   (44, 1.0),
#   (49, 1.0),
#   (50, 1.0),
#   (51, 1.0),
#   (52, 1.0),
#   (53, 1.0),
#   (54, 1.0),
#   (55, 1.0),
#   (56, 1.0),
#   (57, 1.0),
#   (58, 1.0),
#   (59, 1.0),
#   (60, 1.0),
#   (61, 1.0),
#   (62, 1.0),
#   (63, 1.0),
#   (64, 1.0),
#   (65, 1.0),
#   (66, 1.0),
#   (67, 1.0),
#   (68, 1.0),
#   (69, 1.0),
#   (70, 1.0),
#   (71, 1.0),
#   (72, 1.0),
#   (73, 1.0),
#   (74, 1.0),
#   (75, 1.0),
#   (76, 1.0),
#   (77, 1.0),
#   (78, 1.0),
#   (79, 1.0),
#   (80, 1.0),
#   (81, 1.0),
#   (82, 1.0),
#   (83, 1.0),
#   (84, 1.0),
#   (85, 1.0),
#   (86, 1.0),
#   (87, 1.0),
#   (88, 1.0),
#   (89, 1.0),
#   (90, 1.0),
#   (91, 1.0),
#   (92, 1.0),
#   (93, 1.0),
#   (94, 1.0),
#   (95, 1.0),
#   (96, 1.0),
#   (97, 1.0),
#   (98, 1.0),
#   (99, 1.0),
#   (100, 1.0),
#   (101, 1.0),
#   (102, 1.0),
#   (103, 1.0),
#   (104, 1.0),
#   (105, 1.0),
#   (106, 1.0),
#   (107, 1.0),
#   (108, 1.0),
#   (109, 1.0),
#   (110, 1.0),
#   (111, 1.0),
#   (112, 1.0),
#   (113, 1.0),
#   (114, 1.0),
#   (115, 1.0),
#   (116, 1.0),
#   (117, 1.0),
#   (118, 1.0),
#   (119, 1.0),
#   (120, 1.0),
#   (121, 1.0),
#   (122, 1.0),
#   (123, 1.0),
#   (124, 1.0),
#   (125, 1.0),
#   (126, 1.0),
#   (127, 1.0),
#   (128, 1.0),
#   (129, 1.0),
#   (130, 1.0),
#   (131, 1.0),
#   (132, 1.0),
#   (133, 1.0),
#   (134, 1.0),
#   (135, 1.0),
#   (136, 1.0),
#   (137, 1.0),
#   (138, 1.0),
#   (139, 1.0),
#   (140, 1.0),
#   (141, 1.0),
#   (142, 1.0),
#   (143, 1.0),
#   (144, 1.0),
#   (145, 1.0),
#   (146, 1.0),
#   (147, 1.0),
#   (148, 1.0),
#   (149, 1.0),
#   (150, 1.0),
#   (151, 1.0),
#   (152, 1.0),
#   (153, 1.0),
#   (154, 1.0),
#   (155, 1.0),
#   (156, 1.0),
#   (157, 1.0),
#   (158, 1.0),
#   (159, 1.0),
#   (160, 1.0),
#   (161, 1.0),
#   (162, 1.0),
#   (163, 1.0),
#   (164, 1.0),
#   (165, 1.0),
#   (166, 1.0),
#   (167, 1.0),
#   (168, 1.0),
#   (169, 1.0),
#   (170, 1.0),
#   (171, 1.0),
#   (172, 1.0),
#   (173, 1.0),
#   (174, 1.0),
#   (175, 1.0),
#   (176, 1.0),
#   (177, 1.0),
#   (178, 1.0),
#   (179, 1.0),
#   (180, 1.0),
#   (181, 1.0),
#   (182, 1.0),
#   (183, 1.0),
#   (184, 1.0),
#   (185, 1.0),
#   (186, 1.0),
#   (187, 1.0),
#   (188, 1.0),
#   (189, 1.0),
#   (190, 1.0),
#   (191, 1.0),
#   (192, 1.0),
#   (193, 1.0),
#   (194, 1.0),
#   (195, 1.0),
#   (196, 1.0),
#   (197, 1.0),
#   (198, 1.0),
#   (199, 1.0),
#   (200, 1.0),
#   (201, 1.0),
#   (202, 1.0),
#   (203, 1.0),
#   (204, 1.0),
#   (205, 1.0),
#   (206, 1.0),
#   (207, 1.0),
#   (208, 1.0),
#   (209, 1.0),
#   (210, 1.0),
#   (211, 1.0),
#   (212, 1.0),
#   (213, 1.0),
#   (214, 1.0),
#   (215, 1.0),
#   (216, 1.0),
#   (217, 1.0),
#   (218, 1.0),
#   (219, 1.0),
#   (220, 1.0),
#   (221, 1.0),
#   (222, 1.0),
#   (223, 1.0),
#   (224, 1.0),
#   (225, 1.0),
#   (226, 1.0),
#   (227, 1.0),
#   (228, 1.0),
#   (229, 1.0),
#   (230, 1.0),
#   (231, 1.0),
#   (232, 1.0),
#   (233, 1.0),
#   (234, 1.0),
#   (235, 1.0),
#   (236, 1.0),
#   (237, 1.0),
#   (238, 1.0),
#   (239, 1.0),
#   (240, 1.0),
#   (241, 1.0),
#   (242, 1.0),
#   (243, 1.0),
#   (244, 1.0),
#   (245, 1.0),
#   (246, 1.0),
#   (247, 1.0),
#   (248, 1.0),
#   (249, 1.0),
#   (250, 1.0),
#   (251, 1.0),
#   (252, 1.0),
#   (253, 1.0),
#   (254, 1.0),
#   (255, 1.0),
#   (256, 1.0),
#   (257, 1.0),
#   (258, 1.0),
#   (259, 1.0),
#   (260, 1.0),
#   (261, 1.0),
#   (262, 1.0),
#   (263, 1.0),
#   (264, 1.0),
#   (265, 1.0),
#   (266, 1.0),
#   (267, 1.0),
#   (268, 1.0),
#   (272, 1.0),
#   (273, 1.0),
#   (274, 1.0),
#   (275, 1.0),
#   (276, 1.0),
#   (277, 1.0),
#   (278, 1.0),
#   (279, 1.0),
#   (280, 1.0),
#   (281, 1.0),
#   (282, 1.0),
#   (283, 1.0),
#   (284, 1.0),
#   (285, 1.0),
#   (286, 1.0),
#   (287, 1.0),
#   (288, 1.0),
#   (292, 1.0),
#   (293, 1.0),
#   (294, 1.0),
#   (295, 1.0),
#   (296, 1.0),
#   (297, 1.0),
#   (298, 1.0),
#   (299, 1.0),
#   (300, 1.0),
#   (301, 1.0),
#   (302, 1.0),
#   (303, 1.0),
#   (304, 1.0),
#   (305, 1.0),
#   (306, 1.0),
#   (307, 1.0),
#   (308, 1.0),
#   (309, 1.0),
#   (310, 1.0),
#   (311, 1.0),
#   (312, 1.0),
#   (313, 1.0),
#   (323, 1.0),
#   (324, 1.0),
#   (325, 1.0),
#   (326, 1.0),
#   (327, 1.0),
#   (328, 1.0),
#   (329, 1.0),
#   (330, 1.0),
#   (331, 1.0),
#   (332, 1.0),
#   (333, 1.0),
#   (334, 1.0),
#   (335, 1.0),
#   (336, 1.0),
#   (337, 1.0),
#   (338, 1.0),
#   (339, 1.0),
#   (340, 1.0),
#   (341, 1.0),
#   (342, 1.0),
#   (343, 1.0),
#   (344, 1.0),
#   (345, 1.0),
#   (346, 1.0),
#   (347, 1.0),
#   (348, 1.0),
#   (349, 1.0),
#   (350, 1.0),
#   (351, 1.0),
#   (352, 1.0),
#   (353, 1.0),
#   (354, 1.0),
#   (355, 1.0),
#   (356, 1.0),
#   (357, 1.0),
#   (358, 1.0),
#   (359, 1.0),
#   (360, 1.0),
#   (361, 1.0),
#   (362, 1.0),
#   (363, 1.0),
#   (364, 1.0),
#   (365, 1.0),
#   (366, 1.0),
#   (367, 1.0),
#   (368, 1.0),
#   (369, 1.0),
#   (370, 1.0),
#   (371, 1.0),
#   (372, 1.0),
#   (373, 1.0),
#   (374, 1.0),
#   (375, 1.0),
#   (376, 1.0),
#   (377, 1.0),
#   (378, 1.0),
#   (379, 1.0),
#   (380, 1.0),
#   (381, 1.0),
#   (382, 1.0),
#   (383, 1.0),
#   (384, 1.0),
#   (385, 1.0),
#   (386, 1.0),
#   (387, 1.0),
#   (388, 1.0),
#   (389, 1.0),
#   (390, 1.0),
#   (391, 1.0),
#   (392, 1.0),
#   (393, 1.0),
#   (394, 1.0),
#   (395, 1.0),
#   (396, 1.0),
#   (397, 1.0),
#   (398, 1.0),
#   (399, 1.0),
#   (400, 1.0),
#   (401, 1.0),
#   (402, 1.0),
#   (403, 1.0),
#   (404, 1.0),
#   (405, 1.0),
#   (406, 1.0),
#   (407, 1.0),
#   (408, 1.0),
#   (409, 1.0),
#   (410, 1.0),
#   (411, 1.0),
#   (412, 1.0),
#   (413, 1.0),
#   (414, 1.0),
#   (415, 1.0),
#   (416, 1.0),
#   (417, 1.0),
#   (418, 1.0),
#   (419, 1.0),
#   (420, 1.0),
#   (421, 1.0),
#   (422, 1.0),
#   (423, 1.0),
#   (424, 1.0),
#   (425, 1.0),
#   (426, 1.0),
#   (427, 1.0),
#   (428, 1.0),
#   (429, 1.0),
#   (430, 1.0),
#   (431, 1.0),
#   (432, 1.0),
#   (433, 1.0),
#   (434, 1.0),
#   (435, 1.0),
#   (436, 1.0),
#   (437, 1.0),
#   (438, 1.0),
#   (439, 1.0),
#   (440, 1.0),
#   (441, 1.0),
#   (442, 1.0),
#   (443, 1.0),
#   (444, 1.0),
#   (445, 1.0),
#   (446, 1.0),
#   (447, 1.0),
#   (448, 1.0),
#   (449, 1.0),
#   (450, 1.0),
#   (451, 1.0),
#   (452, 1.0),
#   (453, 1.0),
#   (454, 1.0),
#   (455, 1.0),
#   (456, 1.0),
#   (457, 1.0),
#   (458, 1.0),
#   (459, 1.0),
#   (460, 1.0),
#   (461, 1.0),
#   (462, 1.0),
#   (463, 1.0),
#   (464, 1.0),
#   (465, 1.0),
#   (466, 1.0),
#   (467, 1.0),
#   (468, 1.0),
#   (469, 1.0),
#   (470, 1.0),
#   (471, 1.0),
#   (472, 1.0),
#   (473, 1.0),
#   (474, 1.0),
#   (475, 1.0),
#   (476, 1.0),
#   (477, 1.0),
#   (478, 1.0),
#   (479, 1.0),
#   (480, 1.0),
#   (481, 1.0),
#   (482, 1.0),
#   (483, 1.0),
#   (484, 1.0),
#   (485, 1.0),
#   (486, 1.0),
#   (487, 1.0),
#   (488, 1.0),
#   (489, 1.0),
#   (490, 1.0),
#   (491, 1.0),
#   (492, 1.0),
#   (493, 1.0),
#   (494, 1.0),
#   (495, 1.0),
#   (496, 1.0),
#   (497, 1.0),
#   (498, 1.0),
#   (499, 1.0),
#   (500, 1.0),
#   (501, 1.0),
#   (502, 1.0),
#   (503, 1.0),
#   (504, 1.0),
#   (505, 1.0),
#   (506, 1.0),
#   (507, 1.0),
#   (508, 1.0),
#   (509, 1.0),
#   (510, 1.0),
#   (511, 1.0),
#   (512, 1.0),
#   (513, 1.0),
#   (514, 1.0),
#   (515, 1.0),
#   (516, 1.0),
#   (517, 1.0),
#   (518, 1.0),
#   (519, 1.0),
#   (520, 1.0),
#   (521, 1.0),
#   (522, 1.0),
#   (523, 1.0),
#   (524, 1.0),
#   (525, 1.0),
#   (526, 1.0),
#   (527, 1.0),
#   (528, 1.0),
#   (529, 1.0),
#   (530, 1.0),
#   (531, 1.0),
#   (532, 1.0),
#   (533, 1.0),
#   (534, 1.0),
#   (535, 1.0),
#   (536, 1.0),
#   (537, 1.0),
#   (538, 1.0),
#   (539, 1.0),
#   (540, 1.0),
#   (541, 1.0),
#   (542, 1.0),
#   (543, 1.0),
#   (544, 1.0),
#   (545, 1.0),
#   (546, 1.0),
#   (547, 1.0),
#   (548, 1.0),
#   (549, 1.0),
#   (550, 1.0),
#   (551, 1.0),
#   (552, 1.0),
#   (553, 1.0),
#   (554, 1.0),
#   (555, 1.0),
#   (556, 1.0),
#   (557, 1.0),
#   (558, 1.0),
#   (559, 1.0),
#   (560, 1.0),
#   (561, 1.0),
#   (562, 1.0),
#   (563, 1.0),
#   (564, 1.0),
#   (565, 1.0),
#   (566, 1.0),
#   (567, 1.0),
#   (568, 1.0),
#   (569, 1.0),
#   (570, 1.0),
#   (571, 1.0),
#   (572, 1.0),
#   (573, 1.0),
#   (574, 1.0),
#   (575, 1.0),
#   (576, 1.0),
#   (577, 1.0),
#   (578, 1.0),
#   (579, 1.0),
#   (580, 1.0),
#   (581, 1.0),
#   (582, 1.0),
#   (583, 1.0),
#   (584, 1.0),
#   (585, 1.0),
#   (586, 1.0),
#   (587, 1.0),
#   (588, 1.0),
#   (589, 1.0),
#   (590, 1.0),
#   (591, 1.0),
#   (592, 1.0),
#   (593, 1.0),
#   (594, 1.0),
#   (595, 1.0),
#   (596, 1.0),
#   (597, 1.0),
#   (598, 1.0),
#   (599, 1.0),
#   (600, 1.0),
#   (601, 1.0),
#   (602, 1.0),
#   (603, 1.0),
#   (604, 1.0),
#   (605, 1.0),
#   (606, 1.0),
#   (607, 1.0),
#   (608, 1.0),
#   (609, 1.0),
#   (610, 1.0),
#   (611, 1.0),
#   (612, 1.0),
#   (613, 1.0),
#   (614, 1.0),
#   (615, 1.0),
#   (616, 1.0),
#   (617, 1.0),
#   (618, 1.0),
#   (619, 1.0),
#   (620, 1.0),
#   (621, 1.0),
#   (622, 1.0),
#   (623, 1.0),
#   (624, 1.0),
#   (625, 1.0),
#   (626, 1.0),
#   (627, 1.0),
#   (628, 1.0),
#   (629, 1.0),
#   (630, 1.0),
#   (631, 1.0),
#   (632, 1.0),
#   (633, 1.0),
#   (634, 1.0),
#   (635, 1.0),
#   (636, 1.0),
#   (637, 1.0),
#   (638, 1.0),
#   (639, 1.0),
#   (640, 1.0),
#   (641, 1.0),
#   (642, 1.0),
#   (643, 1.0),
#   (644, 1.0),
#   (645, 1.0),
#   (646, 1.0),
#   (647, 1.0),
#   (648, 1.0),
#   (649, 1.0),
#   (650, 1.0),
#   (651, 1.0),
#   (652, 1.0),
#   (653, 1.0),
#   (654, 1.0),
#   (655, 1.0),
#   (656, 1.0),
#   (657, 1.0),
#   (658, 1.0),
#   (659, 1.0),
#   (660, 1.0),
#   (661, 1.0),
#   (662, 1.0),
#   (663, 1.0),
#   (664, 1.0),
#   (665, 1.0),
#   (666, 1.0),
#   (667, 1.0),
#   (668, 1.0),
#   (669, 1.0),
#   (670, 1.0),
#   (671, 1.0),
#   (672, 1.0),
#   (673, 1.0),
#   (674, 1.0),
#   (675, 1.0),
#   (676, 1.0),
#   (677, 1.0),
#   (678, 1.0),
#   (679, 1.0),
#   (680, 1.0),
#   (681, 1.0),
#   (682, 1.0),
#   (683, 1.0),
#   (684, 1.0),
#   (685, 1.0),
#   (686, 1.0),
#   (687, 1.0),
#   (688, 1.0),
#   (689, 1.0),
#   (690, 1.0),
#   (691, 1.0),
#   (692, 1.0),
#   (693, 1.0),
#   (694, 1.0),
#   (695, 1.0),
#   (696, 1.0),
#   (697, 1.0),
#   (698, 1.0),
#   (699, 1.0),
#   (700, 1.0),
#   (701, 1.0),
#   (702, 1.0),
#   (703, 1.0),
#   (704, 1.0),
#   (705, 1.0),
#   (706, 1.0),
#   (707, 1.0),
#   (708, 1.0),
#   (709, 1.0),
#   (710, 1.0),
#   (711, 1.0),
#   (712, 1.0),
#   (713, 1.0),
#   (714, 1.0),
#   (715, 1.0),
#   (716, 1.0),
#   (717, 1.0),
#   (718, 1.0),
#   (719, 1.0),
#   (720, 1.0),
#   (721, 1.0),
#   (722, 1.0),
#   (723, 1.0),
#   (724, 1.0),
#   (725, 1.0),
#   (726, 1.0),
#   (727, 1.0),
#   (728, 1.0),
#   (729, 1.0),
#   (730, 1.0),
#   (731, 1.0),
#   (732, 1.0),
#   (733, 1.0),
#   (734, 1.0),
#   (735, 1.0),
#   (736, 1.0),
#   (737, 1.0),
#   (738, 1.0),
#   (739, 1.0),
#   (740, 1.0),
#   (741, 1.0),
#   (742, 1.0),
#   (743, 1.0),
#   (744, 1.0),
#   (745, 1.0),
#   (746, 1.0),
#   (747, 1.0),
#   (748, 1.0),
#   (749, 1.0),
#   (750, 1.0),
#   (751, 1.0),
#   (752, 1.0),
#   (753, 1.0),
#   (754, 1.0),
#   (755, 1.0),
#   (756, 1.0),
#   (757, 1.0),
#   (758, 1.0),
#   (759, 1.0),
#   (760, 1.0),
#   (761, 1.0),
#   (762, 1.0),
#   (763, 1.0),
#   (764, 1.0),
#   (765, 1.0),
#   (766, 1.0),
#   (767, 1.0),
#   (768, 1.0),
#   (769, 1.0),
#   (770, 1.0),
#   (771, 1.0),
#   (772, 1.0),
#   (773, 1.0),
#   (774, 1.0),
#   (775, 1.0),
#   (776, 1.0),
#   (777, 1.0),
#   (778, 1.0),
#   (779, 1.0),
#   (780, 1.0),
#   (781, 1.0),
#   (782, 1.0),
#   (783, 1.0),
#   (784, 1.0),
#   (785, 1.0),
#   (786, 1.0),
#   (787, 1.0),
#   (788, 1.0),
#   (789, 1.0),
#   (790, 1.0),
#   (791, 1.0)])

# %%
precision[1]
# Out:
# ('freada_agressiva',
#  [(267, 0.6666666666666666),
#   (268, 0.6666666666666666),
#   (269, 0.5),
#   (270, 0.5),
#   (271, 0.5),
#   (286, 0.6666666666666666),
#   (288, 0.6666666666666666),
#   (289, 0.5),
#   (290, 0.5),
#   (291, 0.5),
#   (314, 0.5),
#   (315, 0.5),
#   (316, 0.5),
#   (317, 0.5),
#   (318, 0.5),
#   (319, 0.5),
#   (320, 0.5),
#   (321, 0.5),
#   (322, 0.3333333333333333),
#   (0, 0.5),
#   (1, 0.5),
#   (2, 0.5),
#   (3, 0.5),
#   (4, 0.5),
#   (5, 0.5),
#   (6, 0.5),
#   (7, 0.5),
#   (8, 0.5),
#   (9, 0.5),
#   (10, 0.5),
#   (11, 0.5),
#   (12, 0.5),
#   (13, 0.5),
#   (14, 0.5),
#   (15, 0.5),
#   (16, 0.5),
#   (17, 0.5),
#   (18, 0.5),
#   (19, 0.5),
#   (20, 0.5),
#   (21, 0.5),
#   (27, 0.5),
#   (28, 0.5),
#   (29, 0.5),
#   (30, 0.5),
#   (31, 0.5),
#   (32, 0.5),
#   (33, 0.5),
#   (34, 0.5),
#   (35, 0.5),
#   (36, 0.5),
#   (37, 0.5),
#   (38, 0.5),
#   (39, 0.5),
#   (42, 0.5),
#   (43, 0.5),
#   (44, 0.5),
#   (49, 0.5),
#   (50, 0.5),
#   (51, 0.5),
#   (52, 0.5),
#   (53, 0.5),
#   (54, 0.5),
#   (55, 0.5),
#   (56, 0.5),
#   (57, 0.5),
#   (58, 0.5),
#   (59, 0.5),
#   (60, 0.5),
#   (61, 0.5),
#   (62, 0.5),
#   (63, 0.5),
#   (64, 0.5),
#   (65, 0.5),
#   (66, 0.5),
#   (67, 0.5),
#   (68, 0.5),
#   (69, 0.5),
#   (70, 0.5),
#   (71, 0.5),
#   (72, 0.5),
#   (73, 0.5),
#   (74, 0.5),
#   (75, 0.5),
#   (76, 0.5),
#   (77, 0.5),
#   (78, 0.5),
#   (79, 0.5),
#   (80, 0.5),
#   (81, 0.5),
#   (82, 0.5),
#   (83, 0.5),
#   (84, 0.5),
#   (85, 0.5),
#   (86, 0.5),
#   (87, 0.5),
#   (88, 0.5),
#   (89, 0.5),
#   (90, 0.5),
#   (91, 0.5),
#   (92, 0.5),
#   (93, 0.5),
#   (94, 0.5),
#   (95, 0.5),
#   (96, 0.5),
#   (97, 0.5),
#   (98, 0.5),
#   (99, 0.5),
#   (100, 0.5),
#   (101, 0.5),
#   (102, 0.5),
#   (103, 0.5),
#   (104, 0.5),
#   (105, 0.5),
#   (106, 0.5),
#   (107, 0.5),
#   (108, 0.5),
#   (109, 0.5),
#   (110, 0.5),
#   (111, 0.5),
#   (112, 0.5),
#   (113, 0.5),
#   (114, 0.5),
#   (115, 0.5),
#   (116, 0.5),
#   (117, 0.5),
#   (118, 0.5),
#   (119, 0.5),
#   (120, 0.5),
#   (121, 0.5),
#   (122, 0.5),
#   (123, 0.5),
#   (124, 0.5),
#   (125, 0.5),
#   (126, 0.5),
#   (127, 0.5),
#   (128, 0.5),
#   (129, 0.5),
#   (130, 0.5),
#   (131, 0.5),
#   (132, 0.5),
#   (133, 0.5),
#   (134, 0.5),
#   (135, 0.5),
#   (136, 0.5),
#   (137, 0.5),
#   (138, 0.5),
#   (139, 0.5),
#   (140, 0.5),
#   (141, 0.5),
#   (142, 0.5),
#   (143, 0.5),
#   (144, 0.5),
#   (145, 0.5),
#   (146, 0.5),
#   (147, 0.5),
#   (148, 0.5),
#   (149, 0.5),
#   (150, 0.5),
#   (151, 0.5),
#   (152, 0.5),
#   (153, 0.5),
#   (154, 0.5),
#   (155, 0.5),
#   (156, 0.5),
#   (157, 0.5),
#   (158, 0.5),
#   (159, 0.5),
#   (160, 0.5),
#   (161, 0.5),
#   (162, 0.5),
#   (163, 0.5),
#   (164, 0.5),
#   (165, 0.5),
#   (166, 0.5),
#   (167, 0.5),
#   (168, 0.5),
#   (169, 0.5),
#   (170, 0.5),
#   (171, 0.5),
#   (172, 0.5),
#   (173, 0.5),
#   (174, 0.5),
#   (175, 0.5),
#   (176, 0.5),
#   (177, 0.5),
#   (178, 0.5),
#   (179, 0.5),
#   (180, 0.5),
#   (181, 0.5),
#   (182, 0.5),
#   (183, 0.5),
#   (184, 0.5),
#   (185, 0.5),
#   (186, 0.5),
#   (187, 0.5),
#   (188, 0.5),
#   (189, 0.5),
#   (190, 0.5),
#   (191, 0.5),
#   (192, 0.5),
#   (193, 0.5),
#   (194, 0.5),
#   (195, 0.5),
#   (196, 0.5),
#   (197, 0.5),
#   (198, 0.5),
#   (199, 0.5),
#   (200, 0.5),
#   (201, 0.5),
#   (202, 0.5),
#   (203, 0.5),
#   (204, 0.5),
#   (205, 0.5),
#   (206, 0.5),
#   (207, 0.5),
#   (208, 0.5),
#   (209, 0.5),
#   (210, 0.5),
#   (211, 0.5),
#   (212, 0.5),
#   (213, 0.5),
#   (214, 0.5),
#   (215, 0.5),
#   (216, 0.5),
#   (217, 0.5),
#   (218, 0.5),
#   (219, 0.5),
#   (220, 0.5),
#   (221, 0.5),
#   (222, 0.5),
#   (223, 0.5),
#   (224, 0.5),
#   (225, 0.5),
#   (226, 0.5),
#   (227, 0.5),
#   (228, 0.5),
#   (229, 0.5),
#   (230, 0.5),
#   (231, 0.5),
#   (232, 0.5),
#   (233, 0.5),
#   (234, 0.5),
#   (235, 0.5),
#   (236, 0.5),
#   (237, 0.5),
#   (238, 0.5),
#   (239, 0.5),
#   (240, 0.5),
#   (241, 0.5),
#   (242, 0.5),
#   (243, 0.5),
#   (244, 0.5),
#   (245, 0.5),
#   (246, 0.5),
#   (247, 0.5),
#   (248, 0.5),
#   (249, 0.5),
#   (250, 0.5),
#   (251, 0.5),
#   (252, 0.5),
#   (253, 0.5),
#   (254, 0.5),
#   (255, 0.5),
#   (256, 0.5),
#   (257, 0.5),
#   (258, 0.5),
#   (259, 0.5),
#   (260, 0.5),
#   (261, 0.5),
#   (262, 0.5),
#   (263, 0.5),
#   (264, 0.5),
#   (265, 0.5),
#   (266, 0.5),
#   (272, 0.5),
#   (273, 0.5),
#   (274, 0.5),
#   (275, 0.5),
#   (276, 0.5),
#   (277, 0.5),
#   (278, 0.5),
#   (279, 0.5),
#   (280, 0.5),
#   (281, 0.5),
#   (282, 0.5),
#   (283, 0.5),
#   (284, 0.5),
#   (285, 0.5),
#   (287, 0.5),
#   (292, 0.5),
#   (293, 0.5),
#   (294, 0.5),
#   (295, 0.5),
#   (296, 0.5),
#   (297, 0.5),
#   (298, 0.5),
#   (299, 0.5),
#   (300, 0.5),
#   (301, 0.5),
#   (302, 0.5),
#   (303, 0.5),
#   (304, 0.5),
#   (305, 0.5),
#   (306, 0.5),
#   (307, 0.5),
#   (308, 0.5),
#   (309, 0.5),
#   (310, 0.5),
#   (311, 0.5),
#   (312, 0.5),
#   (313, 0.5),
#   (323, 0.5),
#   (324, 0.5),
#   (325, 0.5),
#   (326, 0.5),
#   (327, 0.5),
#   (328, 0.5),
#   (329, 0.5),
#   (330, 0.5),
#   (331, 0.5),
#   (332, 0.5),
#   (333, 0.5),
#   (334, 0.5),
#   (335, 0.5),
#   (336, 0.5),
#   (337, 0.5),
#   (338, 0.5),
#   (339, 0.5),
#   (340, 0.5),
#   (341, 0.5),
#   (342, 0.5),
#   (343, 0.5),
#   (344, 0.5),
#   (345, 0.5),
#   (346, 0.5),
#   (347, 0.5),
#   (348, 0.5),
#   (349, 0.5),
#   (350, 0.5),
#   (351, 0.5),
#   (352, 0.5),
#   (353, 0.5),
#   (354, 0.5),
#   (355, 0.5),
#   (356, 0.5),
#   (357, 0.5),
#   (358, 0.5),
#   (359, 0.5),
#   (360, 0.5),
#   (361, 0.5),
#   (362, 0.5),
#   (363, 0.5),
#   (364, 0.5),
#   (365, 0.5),
#   (366, 0.5),
#   (367, 0.5),
#   (368, 0.5),
#   (369, 0.5),
#   (370, 0.5),
#   (371, 0.5),
#   (372, 0.5),
#   (373, 0.5),
#   (374, 0.5),
#   (375, 0.5),
#   (376, 0.5),
#   (377, 0.5),
#   (378, 0.5),
#   (379, 0.5),
#   (380, 0.5),
#   (381, 0.5),
#   (382, 0.5),
#   (383, 0.5),
#   (384, 0.5),
#   (385, 0.5),
#   (386, 0.5),
#   (387, 0.5),
#   (388, 0.5),
#   (389, 0.5),
#   (390, 0.5),
#   (391, 0.5),
#   (392, 0.5),
#   (393, 0.5),
#   (394, 0.5),
#   (395, 0.5),
#   (396, 0.5),
#   (397, 0.5),
#   (398, 0.5),
#   (399, 0.5),
#   (400, 0.5),
#   (401, 0.5),
#   (402, 0.5),
#   (403, 0.5),
#   (404, 0.5),
#   (405, 0.5),
#   (406, 0.5),
#   (407, 0.5),
#   (408, 0.5),
#   (409, 0.5),
#   (410, 0.5),
#   (411, 0.5),
#   (412, 0.5),
#   (413, 0.5),
#   (414, 0.5),
#   (415, 0.5),
#   (416, 0.5),
#   (417, 0.5),
#   (418, 0.5),
#   (419, 0.5),
#   (420, 0.5),
#   (421, 0.5),
#   (422, 0.5),
#   (423, 0.5),
#   (424, 0.5),
#   (425, 0.5),
#   (426, 0.5),
#   (427, 0.5),
#   (428, 0.5),
#   (429, 0.5),
#   (430, 0.5),
#   (431, 0.5),
#   (432, 0.5),
#   (433, 0.5),
#   (434, 0.5),
#   (435, 0.5),
#   (436, 0.5),
#   (437, 0.5),
#   (438, 0.5),
#   (439, 0.5),
#   (440, 0.5),
#   (441, 0.5),
#   (442, 0.5),
#   (443, 0.5),
#   (444, 0.5),
#   (445, 0.5),
#   (446, 0.5),
#   (447, 0.5),
#   (448, 0.5),
#   (449, 0.5),
#   (450, 0.5),
#   (451, 0.5),
#   (452, 0.5),
#   (453, 0.5),
#   (454, 0.5),
#   (455, 0.5),
#   (456, 0.5),
#   (457, 0.5),
#   (458, 0.5),
#   (459, 0.5),
#   (460, 0.5),
#   (461, 0.5),
#   (462, 0.5),
#   (463, 0.5),
#   (464, 0.5),
#   (465, 0.5),
#   (466, 0.5),
#   (467, 0.5),
#   (468, 0.5),
#   (469, 0.5),
#   (470, 0.5),
#   (471, 0.5),
#   (472, 0.5),
#   (473, 0.5),
#   (474, 0.5),
#   (475, 0.5),
#   (476, 0.5),
#   (477, 0.5),
#   (478, 0.5),
#   (479, 0.5),
#   (480, 0.5),
#   (481, 0.5),
#   (482, 0.5),
#   (483, 0.5),
#   (484, 0.5),
#   (485, 0.5),
#   (486, 0.5),
#   (487, 0.5),
#   (488, 0.5),
#   (489, 0.5),
#   (490, 0.5),
#   (491, 0.5),
#   (492, 0.5),
#   (493, 0.5),
#   (494, 0.5),
#   (495, 0.5),
#   (496, 0.5),
#   (497, 0.5),
#   (498, 0.5),
#   (499, 0.5),
#   (500, 0.5),
#   (501, 0.5),
#   (502, 0.5),
#   (503, 0.5),
#   (504, 0.5),
#   (505, 0.5),
#   (506, 0.5),
#   (507, 0.5),
#   (508, 0.5),
#   (509, 0.5),
#   (510, 0.5),
#   (511, 0.5),
#   (512, 0.5),
#   (513, 0.5),
#   (514, 0.5),
#   (515, 0.5),
#   (516, 0.5),
#   (517, 0.5),
#   (518, 0.5),
#   (519, 0.5),
#   (520, 0.5),
#   (521, 0.5),
#   (522, 0.5),
#   (523, 0.5),
#   (524, 0.5),
#   (525, 0.5),
#   (526, 0.5),
#   (527, 0.5),
#   (528, 0.5),
#   (529, 0.5),
#   (530, 0.5),
#   (531, 0.5),
#   (532, 0.5),
#   (533, 0.5),
#   (534, 0.5),
#   (535, 0.5),
#   (536, 0.5),
#   (537, 0.5),
#   (538, 0.5),
#   (539, 0.5),
#   (540, 0.5),
#   (541, 0.5),
#   (542, 0.5),
#   (543, 0.5),
#   (544, 0.5),
#   (545, 0.5),
#   (546, 0.5),
#   (547, 0.5),
#   (548, 0.5),
#   (549, 0.5),
#   (550, 0.5),
#   (551, 0.5),
#   (552, 0.5),
#   (553, 0.5),
#   (554, 0.5),
#   (555, 0.5),
#   (556, 0.5),
#   (557, 0.5),
#   (558, 0.5),
#   (559, 0.5),
#   (560, 0.5),
#   (561, 0.5),
#   (562, 0.5),
#   (563, 0.5),
#   (564, 0.5),
#   (565, 0.5),
#   (566, 0.5),
#   (567, 0.5),
#   (568, 0.5),
#   (569, 0.5),
#   (570, 0.5),
#   (571, 0.5),
#   (572, 0.5),
#   (573, 0.5),
#   (574, 0.5),
#   (575, 0.5),
#   (576, 0.5),
#   (577, 0.5),
#   (578, 0.5),
#   (579, 0.5),
#   (580, 0.5),
#   (581, 0.5),
#   (582, 0.5),
#   (583, 0.5),
#   (584, 0.5),
#   (585, 0.5),
#   (586, 0.5),
#   (587, 0.5),
#   (588, 0.5),
#   (589, 0.5),
#   (590, 0.5),
#   (591, 0.5),
#   (592, 0.5),
#   (593, 0.5),
#   (594, 0.5),
#   (595, 0.5),
#   (596, 0.5),
#   (597, 0.5),
#   (598, 0.5),
#   (599, 0.5),
#   (600, 0.5),
#   (601, 0.5),
#   (602, 0.5),
#   (603, 0.5),
#   (604, 0.5),
#   (605, 0.5),
#   (606, 0.5),
#   (607, 0.5),
#   (608, 0.5),
#   (609, 0.5),
#   (610, 0.5),
#   (611, 0.5),
#   (612, 0.5),
#   (613, 0.5),
#   (614, 0.5),
#   (615, 0.5),
#   (616, 0.5),
#   (617, 0.5),
#   (618, 0.5),
#   (619, 0.5),
#   (620, 0.5),
#   (621, 0.5),
#   (622, 0.5),
#   (623, 0.5),
#   (624, 0.5),
#   (625, 0.5),
#   (626, 0.5),
#   (627, 0.5),
#   (628, 0.5),
#   (629, 0.5),
#   (630, 0.5),
#   (631, 0.5),
#   (632, 0.5),
#   (633, 0.5),
#   (634, 0.5),
#   (635, 0.5),
#   (636, 0.5),
#   (637, 0.5),
#   (638, 0.5),
#   (639, 0.5),
#   (640, 0.5),
#   (641, 0.5),
#   (642, 0.5),
#   (643, 0.5),
#   (644, 0.5),
#   (645, 0.5),
#   (646, 0.5),
#   (647, 0.5),
#   (648, 0.5),
#   (649, 0.5),
#   (650, 0.5),
#   (651, 0.5),
#   (652, 0.5),
#   (653, 0.5),
#   (654, 0.5),
#   (655, 0.5),
#   (656, 0.5),
#   (657, 0.5),
#   (658, 0.5),
#   (659, 0.5),
#   (660, 0.5),
#   (661, 0.5),
#   (662, 0.5),
#   (663, 0.5),
#   (664, 0.5),
#   (665, 0.5),
#   (666, 0.5),
#   (667, 0.5),
#   (668, 0.5),
#   (669, 0.5),
#   (670, 0.5),
#   (671, 0.5),
#   (672, 0.5),
#   (673, 0.5),
#   (674, 0.5),
#   (675, 0.5),
#   (676, 0.5),
#   (677, 0.5),
#   (678, 0.5),
#   (679, 0.5),
#   (680, 0.5),
#   (681, 0.5),
#   (682, 0.5),
#   (683, 0.5),
#   (684, 0.5),
#   (685, 0.5),
#   (686, 0.5),
#   (687, 0.5),
#   (688, 0.5),
#   (689, 0.5),
#   (690, 0.5),
#   (691, 0.5),
#   (692, 0.5),
#   (693, 0.5),
#   (694, 0.5),
#   (695, 0.5),
#   (696, 0.5),
#   (697, 0.5),
#   (698, 0.5),
#   (699, 0.5),
#   (700, 0.5),
#   (701, 0.5),
#   (702, 0.5),
#   (703, 0.5),
#   (704, 0.5),
#   (705, 0.5),
#   (706, 0.5),
#   (707, 0.5),
#   (708, 0.5),
#   (709, 0.5),
#   (710, 0.5),
#   (711, 0.5),
#   (712, 0.5),
#   (713, 0.5),
#   (714, 0.5),
#   (715, 0.5),
#   (716, 0.5),
#   (717, 0.5),
#   (718, 0.5),
#   (719, 0.5),
#   (720, 0.5),
#   (721, 0.5),
#   (722, 0.5),
#   (723, 0.5),
#   (724, 0.5),
#   (725, 0.5),
#   (726, 0.5),
#   (727, 0.5),
#   (728, 0.5),
#   (729, 0.5),
#   (730, 0.5),
#   (731, 0.5),
#   (732, 0.5),
#   (733, 0.5),
#   (734, 0.5),
#   (735, 0.5),
#   (736, 0.5),
#   (737, 0.5),
#   (738, 0.5),
#   (739, 0.5),
#   (740, 0.5),
#   (741, 0.5),
#   (742, 0.5),
#   (743, 0.5),
#   (744, 0.5),
#   (745, 0.5),
#   (746, 0.5),
#   (747, 0.5),
#   (748, 0.5),
#   (749, 0.5),
#   (750, 0.5),
#   (751, 0.5),
#   (752, 0.5),
#   (753, 0.5),
#   (754, 0.5),
#   (755, 0.5),
#   (756, 0.5),
#   (757, 0.5),
#   (758, 0.5),
#   (759, 0.5),
#   (760, 0.5),
#   (761, 0.5),
#   (762, 0.5),
#   (763, 0.5),
#   (764, 0.5),
#   (765, 0.5),
#   (766, 0.5),
#   (767, 0.5),
#   (768, 0.5),
#   (769, 0.5),
#   (770, 0.5),
#   (771, 0.5),
#   (772, 0.5),
#   (773, 0.5),
#   (774, 0.5),
#   (775, 0.5),
#   (776, 0.5),
#   (777, 0.5),
#   (778, 0.5),
#   (779, 0.5),
#   (780, 0.5),
#   (781, 0.5),
#   (782, 0.5),
#   (783, 0.5),
#   (784, 0.5),
#   (785, 0.5),
#   (786, 0.5),
#   (787, 0.5),
#   (788, 0.5),
#   (789, 0.5),
#   (790, 0.5),
#   (791, 0.5)])

# %%
precision[2]
# Out:
# ('aceleracao_agressiva',
#  [(0, 1.0),
#   (1, 1.0),
#   (2, 1.0),
#   (3, 1.0),
#   (4, 1.0),
#   (5, 1.0),
#   (6, 1.0),
#   (7, 1.0),
#   (8, 1.0),
#   (9, 1.0),
#   (10, 1.0),
#   (11, 1.0),
#   (12, 1.0),
#   (13, 1.0),
#   (14, 1.0),
#   (15, 1.0),
#   (16, 1.0),
#   (17, 1.0),
#   (18, 1.0),
#   (19, 1.0),
#   (20, 1.0),
#   (21, 1.0),
#   (27, 1.0),
#   (28, 1.0),
#   (29, 1.0),
#   (30, 1.0),
#   (31, 1.0),
#   (32, 1.0),
#   (33, 1.0),
#   (34, 1.0),
#   (35, 1.0),
#   (36, 1.0),
#   (37, 1.0),
#   (38, 1.0),
#   (39, 1.0),
#   (42, 1.0),
#   (43, 1.0),
#   (44, 1.0),
#   (49, 1.0),
#   (50, 1.0),
#   (51, 1.0),
#   (52, 1.0),
#   (53, 1.0),
#   (54, 1.0),
#   (55, 1.0),
#   (56, 1.0),
#   (57, 1.0),
#   (58, 1.0),
#   (59, 1.0),
#   (60, 1.0),
#   (61, 1.0),
#   (62, 1.0),
#   (63, 1.0),
#   (64, 1.0),
#   (65, 1.0),
#   (66, 1.0),
#   (67, 1.0),
#   (68, 1.0),
#   (69, 1.0),
#   (70, 1.0),
#   (71, 1.0),
#   (72, 1.0),
#   (73, 1.0),
#   (74, 1.0),
#   (75, 1.0),
#   (76, 1.0),
#   (77, 1.0),
#   (78, 1.0),
#   (79, 1.0),
#   (80, 1.0),
#   (81, 1.0),
#   (82, 1.0),
#   (83, 1.0),
#   (84, 1.0),
#   (85, 1.0),
#   (86, 1.0),
#   (87, 1.0),
#   (88, 1.0),
#   (89, 1.0),
#   (90, 1.0),
#   (91, 1.0),
#   (92, 1.0),
#   (93, 1.0),
#   (94, 1.0),
#   (95, 1.0),
#   (96, 1.0),
#   (97, 1.0),
#   (98, 1.0),
#   (99, 1.0),
#   (100, 1.0),
#   (101, 1.0),
#   (102, 1.0),
#   (103, 1.0),
#   (104, 1.0),
#   (105, 1.0),
#   (106, 1.0),
#   (107, 1.0),
#   (108, 1.0),
#   (109, 1.0),
#   (110, 1.0),
#   (111, 1.0),
#   (112, 1.0),
#   (113, 1.0),
#   (114, 1.0),
#   (115, 1.0),
#   (116, 1.0),
#   (117, 1.0),
#   (118, 1.0),
#   (119, 1.0),
#   (120, 1.0),
#   (121, 1.0),
#   (122, 1.0),
#   (123, 1.0),
#   (124, 1.0),
#   (125, 1.0),
#   (126, 1.0),
#   (127, 1.0),
#   (128, 1.0),
#   (129, 1.0),
#   (130, 1.0),
#   (131, 1.0),
#   (132, 1.0),
#   (133, 1.0),
#   (134, 1.0),
#   (135, 1.0),
#   (136, 1.0),
#   (137, 1.0),
#   (138, 1.0),
#   (139, 1.0),
#   (140, 1.0),
#   (141, 1.0),
#   (142, 1.0),
#   (143, 1.0),
#   (144, 1.0),
#   (145, 1.0),
#   (146, 1.0),
#   (147, 1.0),
#   (148, 1.0),
#   (149, 1.0),
#   (150, 1.0),
#   (151, 1.0),
#   (152, 1.0),
#   (153, 1.0),
#   (154, 1.0),
#   (155, 1.0),
#   (156, 1.0),
#   (157, 1.0),
#   (158, 1.0),
#   (159, 1.0),
#   (160, 1.0),
#   (161, 1.0),
#   (162, 1.0),
#   (163, 1.0),
#   (164, 1.0),
#   (165, 1.0),
#   (166, 1.0),
#   (167, 1.0),
#   (168, 1.0),
#   (169, 1.0),
#   (170, 1.0),
#   (171, 1.0),
#   (172, 1.0),
#   (173, 1.0),
#   (174, 1.0),
#   (175, 1.0),
#   (176, 1.0),
#   (177, 1.0),
#   (178, 1.0),
#   (179, 1.0),
#   (180, 1.0),
#   (181, 1.0),
#   (182, 1.0),
#   (183, 1.0),
#   (184, 1.0),
#   (185, 1.0),
#   (186, 1.0),
#   (187, 1.0),
#   (188, 1.0),
#   (189, 1.0),
#   (190, 1.0),
#   (191, 1.0),
#   (192, 1.0),
#   (193, 1.0),
#   (194, 1.0),
#   (195, 1.0),
#   (196, 1.0),
#   (197, 1.0),
#   (198, 1.0),
#   (199, 1.0),
#   (200, 1.0),
#   (201, 1.0),
#   (202, 1.0),
#   (203, 1.0),
#   (204, 1.0),
#   (205, 1.0),
#   (206, 1.0),
#   (207, 1.0),
#   (208, 1.0),
#   (209, 1.0),
#   (210, 1.0),
#   (211, 1.0),
#   (212, 1.0),
#   (213, 1.0),
#   (214, 1.0),
#   (215, 1.0),
#   (216, 1.0),
#   (217, 1.0),
#   (218, 1.0),
#   (219, 1.0),
#   (220, 1.0),
#   (221, 1.0),
#   (222, 1.0),
#   (223, 1.0),
#   (224, 1.0),
#   (225, 1.0),
#   (226, 1.0),
#   (227, 1.0),
#   (228, 1.0),
#   (229, 1.0),
#   (230, 1.0),
#   (231, 1.0),
#   (232, 1.0),
#   (233, 1.0),
#   (234, 1.0),
#   (235, 1.0),
#   (236, 1.0),
#   (237, 1.0),
#   (238, 1.0),
#   (239, 1.0),
#   (240, 1.0),
#   (241, 1.0),
#   (242, 1.0),
#   (243, 1.0),
#   (244, 1.0),
#   (245, 1.0),
#   (246, 1.0),
#   (247, 1.0),
#   (248, 1.0),
#   (249, 1.0),
#   (250, 1.0),
#   (251, 1.0),
#   (252, 1.0),
#   (253, 1.0),
#   (254, 1.0),
#   (255, 1.0),
#   (256, 1.0),
#   (257, 1.0),
#   (258, 1.0),
#   (259, 1.0),
#   (260, 1.0),
#   (261, 1.0),
#   (262, 1.0),
#   (263, 1.0),
#   (264, 1.0),
#   (265, 1.0),
#   (266, 1.0),
#   (267, 1.0),
#   (268, 1.0),
#   (272, 1.0),
#   (273, 1.0),
#   (274, 1.0),
#   (275, 1.0),
#   (276, 1.0),
#   (277, 1.0),
#   (278, 1.0),
#   (279, 1.0),
#   (280, 1.0),
#   (281, 1.0),
#   (282, 1.0),
#   (283, 1.0),
#   (284, 1.0),
#   (285, 1.0),
#   (286, 1.0),
#   (287, 1.0),
#   (288, 1.0),
#   (292, 1.0),
#   (293, 1.0),
#   (294, 1.0),
#   (295, 1.0),
#   (296, 1.0),
#   (297, 1.0),
#   (298, 1.0),
#   (299, 1.0),
#   (300, 1.0),
#   (301, 1.0),
#   (302, 1.0),
#   (303, 1.0),
#   (304, 1.0),
#   (305, 1.0),
#   (306, 1.0),
#   (307, 1.0),
#   (308, 1.0),
#   (309, 1.0),
#   (310, 1.0),
#   (311, 1.0),
#   (312, 1.0),
#   (313, 1.0),
#   (323, 1.0),
#   (324, 1.0),
#   (325, 1.0),
#   (326, 1.0),
#   (327, 1.0),
#   (328, 1.0),
#   (329, 1.0),
#   (330, 1.0),
#   (331, 1.0),
#   (332, 1.0),
#   (333, 1.0),
#   (334, 1.0),
#   (335, 1.0),
#   (336, 1.0),
#   (337, 1.0),
#   (338, 1.0),
#   (339, 1.0),
#   (340, 1.0),
#   (341, 1.0),
#   (342, 1.0),
#   (343, 1.0),
#   (344, 1.0),
#   (345, 1.0),
#   (346, 1.0),
#   (347, 1.0),
#   (348, 1.0),
#   (349, 1.0),
#   (350, 1.0),
#   (351, 1.0),
#   (352, 1.0),
#   (353, 1.0),
#   (354, 1.0),
#   (355, 1.0),
#   (356, 1.0),
#   (357, 1.0),
#   (358, 1.0),
#   (359, 1.0),
#   (360, 1.0),
#   (361, 1.0),
#   (362, 1.0),
#   (363, 1.0),
#   (364, 1.0),
#   (365, 1.0),
#   (366, 1.0),
#   (367, 1.0),
#   (368, 1.0),
#   (369, 1.0),
#   (370, 1.0),
#   (371, 1.0),
#   (372, 1.0),
#   (373, 1.0),
#   (374, 1.0),
#   (375, 1.0),
#   (376, 1.0),
#   (377, 1.0),
#   (378, 1.0),
#   (379, 1.0),
#   (380, 1.0),
#   (381, 1.0),
#   (382, 1.0),
#   (383, 1.0),
#   (384, 1.0),
#   (385, 1.0),
#   (386, 1.0),
#   (387, 1.0),
#   (388, 1.0),
#   (389, 1.0),
#   (390, 1.0),
#   (391, 1.0),
#   (392, 1.0),
#   (393, 1.0),
#   (394, 1.0),
#   (395, 1.0),
#   (396, 1.0),
#   (397, 1.0),
#   (398, 1.0),
#   (399, 1.0),
#   (400, 1.0),
#   (401, 1.0),
#   (402, 1.0),
#   (403, 1.0),
#   (404, 1.0),
#   (405, 1.0),
#   (406, 1.0),
#   (407, 1.0),
#   (408, 1.0),
#   (409, 1.0),
#   (410, 1.0),
#   (411, 1.0),
#   (412, 1.0),
#   (413, 1.0),
#   (414, 1.0),
#   (415, 1.0),
#   (416, 1.0),
#   (417, 1.0),
#   (418, 1.0),
#   (419, 1.0),
#   (420, 1.0),
#   (421, 1.0),
#   (422, 1.0),
#   (423, 1.0),
#   (424, 1.0),
#   (425, 1.0),
#   (426, 1.0),
#   (427, 1.0),
#   (428, 1.0),
#   (429, 1.0),
#   (430, 1.0),
#   (431, 1.0),
#   (432, 1.0),
#   (433, 1.0),
#   (434, 1.0),
#   (435, 1.0),
#   (436, 1.0),
#   (437, 1.0),
#   (438, 1.0),
#   (439, 1.0),
#   (440, 1.0),
#   (441, 1.0),
#   (442, 1.0),
#   (443, 1.0),
#   (444, 1.0),
#   (445, 1.0),
#   (446, 1.0),
#   (447, 1.0),
#   (448, 1.0),
#   (449, 1.0),
#   (450, 1.0),
#   (451, 1.0),
#   (452, 1.0),
#   (453, 1.0),
#   (454, 1.0),
#   (455, 1.0),
#   (456, 1.0),
#   (457, 1.0),
#   (458, 1.0),
#   (459, 1.0),
#   (460, 1.0),
#   (461, 1.0),
#   (462, 1.0),
#   (463, 1.0),
#   (464, 1.0),
#   (465, 1.0),
#   (466, 1.0),
#   (467, 1.0),
#   (468, 1.0),
#   (469, 1.0),
#   (470, 1.0),
#   (471, 1.0),
#   (472, 1.0),
#   (473, 1.0),
#   (474, 1.0),
#   (475, 1.0),
#   (476, 1.0),
#   (477, 1.0),
#   (478, 1.0),
#   (479, 1.0),
#   (480, 1.0),
#   (481, 1.0),
#   (482, 1.0),
#   (483, 1.0),
#   (484, 1.0),
#   (485, 1.0),
#   (486, 1.0),
#   (487, 1.0),
#   (488, 1.0),
#   (489, 1.0),
#   (490, 1.0),
#   (491, 1.0),
#   (492, 1.0),
#   (493, 1.0),
#   (494, 1.0),
#   (495, 1.0),
#   (496, 1.0),
#   (497, 1.0),
#   (498, 1.0),
#   (499, 1.0),
#   (500, 1.0),
#   (501, 1.0),
#   (502, 1.0),
#   (503, 1.0),
#   (504, 1.0),
#   (505, 1.0),
#   (506, 1.0),
#   (507, 1.0),
#   (508, 1.0),
#   (509, 1.0),
#   (510, 1.0),
#   (511, 1.0),
#   (512, 1.0),
#   (513, 1.0),
#   (514, 1.0),
#   (515, 1.0),
#   (516, 1.0),
#   (517, 1.0),
#   (518, 1.0),
#   (519, 1.0),
#   (520, 1.0),
#   (521, 1.0),
#   (522, 1.0),
#   (523, 1.0),
#   (524, 1.0),
#   (525, 1.0),
#   (526, 1.0),
#   (527, 1.0),
#   (528, 1.0),
#   (529, 1.0),
#   (530, 1.0),
#   (531, 1.0),
#   (532, 1.0),
#   (533, 1.0),
#   (534, 1.0),
#   (535, 1.0),
#   (536, 1.0),
#   (537, 1.0),
#   (538, 1.0),
#   (539, 1.0),
#   (540, 1.0),
#   (541, 1.0),
#   (542, 1.0),
#   (543, 1.0),
#   (544, 1.0),
#   (545, 1.0),
#   (546, 1.0),
#   (547, 1.0),
#   (548, 1.0),
#   (549, 1.0),
#   (550, 1.0),
#   (551, 1.0),
#   (552, 1.0),
#   (553, 1.0),
#   (554, 1.0),
#   (555, 1.0),
#   (556, 1.0),
#   (557, 1.0),
#   (558, 1.0),
#   (559, 1.0),
#   (560, 1.0),
#   (561, 1.0),
#   (562, 1.0),
#   (563, 1.0),
#   (564, 1.0),
#   (565, 1.0),
#   (566, 1.0),
#   (567, 1.0),
#   (568, 1.0),
#   (569, 1.0),
#   (570, 1.0),
#   (571, 1.0),
#   (572, 1.0),
#   (573, 1.0),
#   (574, 1.0),
#   (575, 1.0),
#   (576, 1.0),
#   (577, 1.0),
#   (578, 1.0),
#   (579, 1.0),
#   (580, 1.0),
#   (581, 1.0),
#   (582, 1.0),
#   (583, 1.0),
#   (584, 1.0),
#   (585, 1.0),
#   (586, 1.0),
#   (587, 1.0),
#   (588, 1.0),
#   (589, 1.0),
#   (590, 1.0),
#   (591, 1.0),
#   (592, 1.0),
#   (593, 1.0),
#   (594, 1.0),
#   (595, 1.0),
#   (596, 1.0),
#   (597, 1.0),
#   (598, 1.0),
#   (599, 1.0),
#   (600, 1.0),
#   (601, 1.0),
#   (602, 1.0),
#   (603, 1.0),
#   (604, 1.0),
#   (605, 1.0),
#   (606, 1.0),
#   (607, 1.0),
#   (608, 1.0),
#   (609, 1.0),
#   (610, 1.0),
#   (611, 1.0),
#   (612, 1.0),
#   (613, 1.0),
#   (614, 1.0),
#   (615, 1.0),
#   (616, 1.0),
#   (617, 1.0),
#   (618, 1.0),
#   (619, 1.0),
#   (620, 1.0),
#   (621, 1.0),
#   (622, 1.0),
#   (623, 1.0),
#   (624, 1.0),
#   (625, 1.0),
#   (626, 1.0),
#   (627, 1.0),
#   (628, 1.0),
#   (629, 1.0),
#   (630, 1.0),
#   (631, 1.0),
#   (632, 1.0),
#   (633, 1.0),
#   (634, 1.0),
#   (635, 1.0),
#   (636, 1.0),
#   (637, 1.0),
#   (638, 1.0),
#   (639, 1.0),
#   (640, 1.0),
#   (641, 1.0),
#   (642, 1.0),
#   (643, 1.0),
#   (644, 1.0),
#   (645, 1.0),
#   (646, 1.0),
#   (647, 1.0),
#   (648, 1.0),
#   (649, 1.0),
#   (650, 1.0),
#   (651, 1.0),
#   (652, 1.0),
#   (653, 1.0),
#   (654, 1.0),
#   (655, 1.0),
#   (656, 1.0),
#   (657, 1.0),
#   (658, 1.0),
#   (659, 1.0),
#   (660, 1.0),
#   (661, 1.0),
#   (662, 1.0),
#   (663, 1.0),
#   (664, 1.0),
#   (665, 1.0),
#   (666, 1.0),
#   (667, 1.0),
#   (668, 1.0),
#   (669, 1.0),
#   (670, 1.0),
#   (671, 1.0),
#   (672, 1.0),
#   (673, 1.0),
#   (674, 1.0),
#   (675, 1.0),
#   (676, 1.0),
#   (677, 1.0),
#   (678, 1.0),
#   (679, 1.0),
#   (680, 1.0),
#   (681, 1.0),
#   (682, 1.0),
#   (683, 1.0),
#   (684, 1.0),
#   (685, 1.0),
#   (686, 1.0),
#   (687, 1.0),
#   (688, 1.0),
#   (689, 1.0),
#   (690, 1.0),
#   (691, 1.0),
#   (692, 1.0),
#   (693, 1.0),
#   (694, 1.0),
#   (695, 1.0),
#   (696, 1.0),
#   (697, 1.0),
#   (698, 1.0),
#   (699, 1.0),
#   (700, 1.0),
#   (701, 1.0),
#   (702, 1.0),
#   (703, 1.0),
#   (704, 1.0),
#   (705, 1.0),
#   (706, 1.0),
#   (707, 1.0),
#   (708, 1.0),
#   (709, 1.0),
#   (710, 1.0),
#   (711, 1.0),
#   (712, 1.0),
#   (713, 1.0),
#   (714, 1.0),
#   (715, 1.0),
#   (716, 1.0),
#   (717, 1.0),
#   (718, 1.0),
#   (719, 1.0),
#   (720, 1.0),
#   (721, 1.0),
#   (722, 1.0),
#   (723, 1.0),
#   (724, 1.0),
#   (725, 1.0),
#   (726, 1.0),
#   (727, 1.0),
#   (728, 1.0),
#   (729, 1.0),
#   (730, 1.0),
#   (731, 1.0),
#   (732, 1.0),
#   (733, 1.0),
#   (734, 1.0),
#   (735, 1.0),
#   (736, 1.0),
#   (737, 1.0),
#   (738, 1.0),
#   (739, 1.0),
#   (740, 1.0),
#   (741, 1.0),
#   (742, 1.0),
#   (743, 1.0),
#   (744, 1.0),
#   (745, 1.0),
#   (746, 1.0),
#   (747, 1.0),
#   (748, 1.0),
#   (749, 1.0),
#   (750, 1.0),
#   (751, 1.0),
#   (752, 1.0),
#   (753, 1.0),
#   (754, 1.0),
#   (755, 1.0),
#   (756, 1.0),
#   (757, 1.0),
#   (758, 1.0),
#   (759, 1.0),
#   (760, 1.0),
#   (761, 1.0),
#   (762, 1.0),
#   (763, 1.0),
#   (764, 1.0),
#   (765, 1.0),
#   (766, 1.0),
#   (767, 1.0),
#   (768, 1.0),
#   (769, 1.0),
#   (770, 1.0),
#   (771, 1.0),
#   (772, 1.0),
#   (773, 1.0),
#   (774, 1.0),
#   (775, 1.0),
#   (776, 1.0),
#   (777, 1.0),
#   (778, 1.0),
#   (779, 1.0),
#   (780, 1.0),
#   (781, 1.0),
#   (782, 1.0),
#   (783, 1.0),
#   (784, 1.0),
#   (785, 1.0),
#   (786, 1.0),
#   (787, 1.0),
#   (788, 1.0),
#   (789, 1.0),
#   (790, 1.0),
#   (791, 1.0)])

# %% [markdown]
# its not good at all , lets optimimize it

# %%
#plot and optimize the number of the cluster and the linkage method
def Mean(dprecision):
    return np.mean(list(dict(dprecision).values()))

def Oploter(number_of_cluster , linkage_method):
    #calculate the precision of clustering by labeled data 
    exploratory_analysis=list()
    for el in ld:
        midle_list=list()
        label_tag =el[0]
        label_distance=el[1].copy()
        label_distance.append(0)
        distance_matrix=dc.copy()
        distance_matrix.append(label_distance)
        DMX=creat_Symmetric_matrix(distance_matrix)
        Labels = AgglomerativeClustering(n_clusters=number_of_cluster, affinity='precomputed', linkage = linkage_method).fit(DMX).labels_

        #extract lable  and labele it from the item we put at the end
        for i , x in enumerate(Labels):
            if i!=(len(Labels)-1):
                if x==Labels[-1]:
                    midle_list.append(i)
        exploratory_analysis.append([label_tag,midle_list])
    actg=dict()
    for ev,x in exploratory_analysis:
        if ev in actg:
            actg[ev].append(x)
        else:
            actg.update({ev:[x]})
    #calculate the Probibility of being event of temp_event
    Prob_threshold=0.1
    precision=list()
    for event_name in actg:
        flat_list=list(dict.fromkeys(flatten(actg[event_name])))
        dprecision=list()
        for S in flat_list:
            x=0
            Number=len(actg[event_name])
            for i in range(Number):
                if S in actg[event_name][i]:
                    x=x+1
            Probability=x/Number
            if Probability > Prob_threshold:
                dprecision.append((S,Probability))
        precision.append((event_name,len(dprecision),Mean(dprecision),dprecision))
    return precision

# %%
#linkage method average
linkage_mth='average'
Ya=list()
t1=time.time()
for num_cl in range(3,50):
    X=Oploter(num_cl,linkage_mth)
    Ya.append(X)
t2=time.time()
print(round((t2-t1)/60) ,'min has time for calculaton distant')
# Out:
# 11 min has time for calculaton distant

# %%
Ya_N1=[x[0][1] for x in Ya]
Ya_N2=[x[1][1] for x in Ya]
Ya_N3=[x[2][1] for x in Ya]

X = range(3,50)
fig, ax = plt.subplots()

ax.plot(X,Ya_N1, linestyle='-', linewidth=2,c='r')
ax.plot(X,Ya_N2, linestyle='-', linewidth=2,c='g')
ax.plot(X,Ya_N3, linestyle='-', linewidth=2,c='b')


ax.legend();
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Ya_Q1=[x[0][2] for x in Ya]
Ya_Q2=[x[1][2] for x in Ya]
Ya_Q3=[x[2][2] for x in Ya]


X = range(3,50)

fig, ax = plt.subplots()

ax.plot(X,Ya_Q1, linestyle='-', linewidth=2,c='r')
ax.plot(X,Ya_Q2, linestyle='-', linewidth=2,c='g')
ax.plot(X,Ya_Q3, linestyle='-', linewidth=2,c='b')
ax.legend();
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Ya_N1=[x[0][1] for x in Ya][0:10]
Ya_N2=[x[1][1] for x in Ya][0:10]

X = range(3,13)
fig, ax = plt.subplots()

ax.plot(X,Ya_N1, linestyle='-', linewidth=2,c='r')
ax.plot(X,Ya_N2, linestyle='-', linewidth=2,c='g')



ax.legend();
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Ya_Q1=[x[0][2] for x in Ya][0:6]
Ya_Q2=[x[1][2] for x in Ya][0:6]


X = range(3,9)

fig, ax = plt.subplots()

ax.plot(X,Ya_Q1, linestyle='-', linewidth=2,c='r')
ax.plot(X,Ya_Q2, linestyle='-', linewidth=2,c='g')

ax.legend();
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Ya_N3=[x[2][1] for x in Ya][40-3:50-3]

X = range(40,50)
fig, ax = plt.subplots()

ax.plot(X,Ya_N3, linestyle='-', linewidth=2,c='b')


ax.legend();
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
Ya_Q3=[x[2][2] for x in Ya][40-3:50-3]


X = range(40,50)

fig, ax = plt.subplots()

ax.plot(X,Ya_Q3, linestyle='-', linewidth=2,c='b')
ax.legend();
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
OptimizeEvent=list()
OptimizeEvent.append(Ya[7-3][0])#red
OptimizeEvent.append(Ya[6-3][1])#green
OptimizeEvent.append(Ya[46-3][2])#blue

#Save labeds distance matrix
with open("OptimizeLabeldEvent_on17.txt", "wb") as fp:
    pickle.dump(OptimizeEvent, fp)

# %%
#load File , save the time of calculation
with open("OptimizeLabeldEvent_on17.txt", "rb") as fp:
    oe = pickle.load(fp)

# %%
oe
# Out:
# [('troca_faixa_direita_agressiva',
#   11,
#   0.9545454545454546,
#   [(30, 1.0),
#    (31, 1.0),
#    (32, 1.0),
#    (33, 1.0),
#    (49, 1.0),
#    (50, 1.0),
#    (51, 1.0),
#    (52, 1.0),
#    (53, 1.0),
#    (54, 1.0),
#    (29, 0.5)]),
#  ('freada_agressiva',
#   31,
#   0.48924731182795694,
#   [(270, 0.5),
#    (271, 0.5),
#    (289, 0.5),
#    (290, 0.5),
#    (291, 0.5),
#    (314, 0.5),
#    (315, 0.5),
#    (316, 0.5),
#    (317, 0.5),
#    (318, 0.5),
#    (319, 0.5),
#    (320, 0.5),
#    (321, 0.5),
#    (322, 0.3333333333333333),
#    (269, 0.3333333333333333),
#    (424, 0.5),
#    (425, 0.5),
#    (426, 0.5),
#    (427, 0.5),
#    (428, 0.5),
#    (429, 0.5),
#    (449, 0.5),
#    (452, 0.5),
#    (453, 0.5),
#    (454, 0.5),
#    (455, 0.5),
#    (476, 0.5),
#    (477, 0.5),
#    (478, 0.5),
#    (479, 0.5),
#    (480, 0.5)]),
#  ('aceleracao_agressiva',
#   29,
#   0.21264367816091956,
#   [(553, 0.16666666666666666),
#    (555, 0.16666666666666666),
#    (556, 0.16666666666666666),
#    (557, 0.3333333333333333),
#    (558, 0.3333333333333333),
#    (559, 0.3333333333333333),
#    (284, 0.16666666666666666),
#    (285, 0.16666666666666666),
#    (287, 0.16666666666666666),
#    (312, 0.16666666666666666),
#    (313, 0.16666666666666666),
#    (590, 0.16666666666666666),
#    (591, 0.16666666666666666),
#    (592, 0.16666666666666666),
#    (593, 0.16666666666666666),
#    (594, 0.16666666666666666),
#    (634, 0.16666666666666666),
#    (635, 0.16666666666666666),
#    (636, 0.16666666666666666),
#    (637, 0.16666666666666666),
#    (638, 0.16666666666666666),
#    (747, 0.3333333333333333),
#    (748, 0.3333333333333333),
#    (749, 0.3333333333333333),
#    (750, 0.3333333333333333),
#    (751, 0.3333333333333333),
#    (777, 0.16666666666666666),
#    (778, 0.16666666666666666),
#    (779, 0.16666666666666666)])]
